# %% [markdown]
# ![image.png](attachment:c40eca76-19d4-477c-9db1-184836df05ed.png)

# %% [markdown]
# MongoDB is an open-source document-oriented database that is designed to store a large scale of data and also allows you to work with that data very efficiently.
#
# Non-relational databases (often called NoSQL databases) are different from traditional relational databases in that they store their data in a non-tabular form.
#
# It is preferred to use mongodb over sql database in following case:
# You're using cloud computing. MongoDB is ideal for cloud computing.
#
# You need your data fast and easily accessible.
#
# You don't have a database administrator.

# %% [markdown]
# ![image.png](attachment:b91d2393-4521-48ca-bbf5-26c31f592615.png)

# %% [markdown]
# Ad-hoc queries for optimized, real-time analytics.
#
# Indexing appropriately for better query executions.
#
# Replication for better data availability and stability.
#
# Sharding.
#
# Load balancing.

# %% [markdown]
# ![image.png](attachment:f059c1fa-67cc-404b-a438-92b2a892e617.png)

# %% [markdown]
# import pymongo
#
# client=pymongo.MongoClient("mongodb+srv://harshagrre11:abes@cluster0.ztq1qgu.mongodb.net/?retryWrites=true&w=majority")
#
# db=client.test
#
# db=client['database']
#
# data={'name':'harsh','roll_n':232232,"key":222121222}
#
# a=db['record']
#
# a.insert_one(data)

# %% [markdown]
# ![image.png](attachment:27948c67-960c-428d-b902-a799e2e176cd.png)

# %% [markdown]
# a.insert_one(data)
#
# a.insert_many(data)
#
# for i in a.find():
#     print(i)

# %% [markdown]
# ![image.png](attachment:e9ceaca3-4d76-40b6-89dc-d60479a1dbb8.png)

# %% [markdown]
# for i in a.find({'name':'harsh'}):
#     print(i)
#
# for i in a.find({'_id':{'$gte':'4'}}):
#     print(i)

# %% [markdown]
# ![image.png](attachment:d187fa23-d13b-4870-a784-6530a5c215cb.png)

# %%
import pymongo
client=pymongo.MongoClient("mongodb+srv://harshagrre11:abes@cluster0.ztq1qgu.mongodb.net/?retryWrites=true&w=majority")
db2=client['database']
b=db2['record2']
data4=[{'age':18,'name':'harsh'},{'age':19,'name':'jarsh'},{'age':20,'name':'oarsh'}]
b.insert_many(data4)
sort=b.find().sort('age', pymongo.ASCENDING)

# %% [markdown]
# ![image.png](attachment:8d27cd6f-84dd-4136-b86d-bd01d1bcb367.png)

# %% [markdown]
# delete_one()
#
# The deleteOne() method deletes the first document from the collection that matches the given selection criteria.
#
# delete_many()
#
# The deleteOne() method deletes the all document from the collection that matches the given selection criteria.
#
# drop()
#
# In MongoDB, db.collection.drop() method is used to drop a collection from a database. It completely removes a collection from the database and does not leave any indexes associated with the dropped collections.
